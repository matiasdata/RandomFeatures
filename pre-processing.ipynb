# %% [markdown]
# ## Computing lagged returns

# %%
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect('db2023.db')

# %%
## Adding lagged returns
query = "SELECT * FROM Prices"
df = pd.read_sql_query(query, conn)
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(by=['permno', 'date'])
for i in range(0, 12):
    df[f'ret_lag_{i+1}'] = df.groupby('permno')['retadj'].shift(i)
df['date'] = df['date'].dt.strftime('%Y-%m-%d')
df.to_sql('Prices_lags', conn, if_exists='replace', index=False)
# Out:
# 4459284

# %%
conn.close()

# %% [markdown]
# ## Processing Characteristics

# %%
# Connect to the SQLite database
conn = sqlite3.connect('db2023.db')
cur = conn.cursor()

# Fetch all distinct dates from the Prices table
dates = pd.read_sql_query('SELECT DISTINCT date FROM Prices_lags', conn)
dates_list = dates['date'].tolist()
dates_list.sort()

# %%
# Columns to use for ratios
cols_ratios = ['CAPEI', 'bm', 'evm', 'pe_op_basic', 'pe_op_dil', 'pe_exi', 'pe_inc', 'ps', 'pcf',
               'dpr', 'npm', 'opmbd', 'opmad', 'gpm', 'ptpm', 'cfm', 'roa', 'roe', 'roce', 'efftax',
               'aftret_eq', 'aftret_invcapx', 'aftret_equity', 'pretret_noa', 'pretret_earnat', 'GProf',
               'equity_invcap', 'debt_invcap', 'totdebt_invcap', 'capital_ratio', 'int_debt', 'int_totdebt',
               'cash_lt', 'invt_act', 'rect_act', 'debt_at', 'debt_ebitda', 'short_debt', 'curr_debt',
               'lt_debt', 'profit_lct', 'ocf_lct', 'cash_debt', 'fcf_ocf', 'lt_ppent', 'dltt_be',
               'debt_assets', 'debt_capital', 'de_ratio', 'intcov', 'intcov_ratio', 'cash_ratio',
               'quick_ratio', 'curr_ratio', 'cash_conversion', 'inv_turn', 'at_turn', 'rect_turn',
               'pay_turn', 'sale_invcap', 'sale_equity', 'sale_nwc', 'rd_sale', 'adv_sale', 'staff_sale',
               'accrual', 'ptb', 'PEG_trailing', 'divyield']

# Columns for lagged returns
cols_lags = [f'ret_lag_{i}' for i in range(1, 13)]

# Initialize an empty DataFrame to store results
results = pd.DataFrame()

# Loop through each date
for date in dates_list[:-1]:
    print(f"Processing date: {date}")

    # Load data for the current date
    crsp = pd.read_sql_query('SELECT * FROM Prices_lags WHERE date = ?', conn, params=(date,))
    wifr = pd.read_sql_query('SELECT * FROM Ratios WHERE public_date LIKE ?', conn, params=(date[:7] + '%',))

    # Ensure the columns are numeric
    for column in cols_ratios:
        wifr[column] = pd.to_numeric(wifr[column], errors='coerce')

    # Merge and filter data
    crsp_cols = ["permno", "mktflag", "dlstcd"] + cols_lags
    wifr_mkt = pd.merge(wifr, crsp[crsp_cols], how="inner", on="permno")
    wifr_mkt = wifr_mkt[(wifr_mkt["mktflag"] == 1) & (wifr_mkt["dlstcd"] == "")]

    # Drop the 'mktflag' column
    wifr_mkt.drop(columns=["mktflag"], inplace=True)

    # Convert lagged return columns to numeric
    for col in cols_lags:
        wifr_mkt[col] = pd.to_numeric(wifr_mkt[col], errors='coerce')

    # Compute normalized ranks for the financial ratios and lagged returns
    df_z = wifr_mkt[["gvkey", "permno", "adate", "qdate", "public_date"]].copy()
    cols_ratios_ext = cols_ratios + cols_lags

    for col in cols_ratios_ext:
        rank = wifr_mkt[col].rank(method="average", na_option='keep', ascending=False)
        n_t = rank.count()
        rc = rank / (n_t + 1)
        mu = rc.mean()
        df_z[col] = (rc - mu) / (np.abs(rc - mu).sum())
        df_z[col] = df_z[col].fillna(0)

    # Fetch the next month's date for returns
    next_date = pd.to_datetime(date) + pd.DateOffset(months=1)
    next_date_str = next_date.strftime('%Y-%m-%d')
    rets = pd.read_sql_query('SELECT * FROM Prices WHERE date LIKE ?', conn, params=(next_date_str[:7]+"%",))
    rets = rets[["permno", "retadj"]]
    rets["retadj"] = pd.to_numeric(rets["retadj"], errors='coerce')
    rets.dropna(inplace=True)

    # Merge with z-scores
    df_y = pd.merge(df_z, rets, how="inner", on="permno")
    df_y.set_index("permno", inplace=True)

    # Add date column to df_y
    df_y["date"] = date

    # Append the result to the results DataFrame
    results = pd.concat([results, df_y])
    print(df_y.shape)

# Write the results DataFrame back to the database
results.to_sql('Z_R_matrices', conn, if_exists='replace', index=True)

# Close the database connection
conn.close()

print("Processing completed.")
# Out:
# Processing date: 1970-01-30
# (950, 87)
# Processing date: 1970-02-27
# (946, 87)
# Processing date: 1970-03-31
# (938, 87)
# Processing date: 1970-04-30
# (912, 87)
# Processing date: 1970-05-29
# (892, 87)
# Processing date: 1970-06-30
# (880, 87)
# Processing date: 1970-07-31
# (874, 87)
# Processing date: 1970-08-31
# (884, 87)
# Processing date: 1970-09-30
# (901, 87)
# Processing date: 1970-10-30
# (889, 87)
# Processing date: 1970-11-30
# (888, 87)
# Processing date: 1970-12-31
# (898, 87)
# Processing date: 1971-01-29
# (920, 87)
# Processing date: 1971-02-26
# (930, 87)
# Processing date: 1971-03-31
# (925, 87)
# Processing date: 1971-04-30
# (909, 87)
# Processing date: 1971-05-28
# (916, 87)
# Processing date: 1971-06-30
# (913, 87)
# Processing date: 1971-07-30
# (911, 87)
# Processing date: 1971-08-31
# (919, 87)
# Processing date: 1971-09-30
# (922, 87)
# Processing date: 1971-10-29
# (920, 87)
# Processing date: 1971-11-30
# (912, 87)
# Processing date: 1971-12-31
# (934, 87)
# Processing date: 1972-01-31
# (954, 87)
# Processing date: 1972-02-29
# (970, 87)
# Processing date: 1972-03-30
# (961, 87)
# Processing date: 1972-04-28
# (968, 87)
# Processing date: 1972-05-31
# (950, 87)
# Processing date: 1972-06-30
# (956, 87)
# Processing date: 1972-07-31
# (932, 87)
# Processing date: 1972-08-31
# (921, 87)
# Processing date: 1972-09-29
# (912, 87)
# Processing date: 1972-10-31
# (903, 87)
# Processing date: 1972-11-30
# (919, 87)
# Processing date: 1972-12-29
# (856, 87)
# Processing date: 1973-01-31
# (842, 87)
# Processing date: 1973-02-28
# (1035, 87)
# Processing date: 1973-03-30
# (1027, 87)
# Processing date: 1973-04-30
# (1005, 87)
# Processing date: 1973-05-31
# (974, 87)
# Processing date: 1973-06-29
# (955, 87)
# Processing date: 1973-07-31
# (977, 87)
# Processing date: 1973-08-31
# (977, 87)
# Processing date: 1973-09-28
# (996, 87)
# Processing date: 1973-10-31
# (990, 87)
# Processing date: 1973-11-30
# (955, 87)
# Processing date: 1973-12-31
# (941, 87)
# Processing date: 1974-01-31
# (986, 87)
# Processing date: 1974-02-28
# (972, 87)
# Processing date: 1974-03-29
# (986, 87)
# Processing date: 1974-04-30
# (975, 87)
# Processing date: 1974-05-31
# (951, 87)
# Processing date: 1974-06-28
# (944, 87)
# Processing date: 1974-07-31
# (951, 87)
# Processing date: 1974-08-30
# (959, 87)
# Processing date: 1974-09-30
# (971, 87)
# Processing date: 1974-10-31
# (930, 87)
# Processing date: 1974-11-29
# (934, 87)
# Processing date: 1974-12-31
# (932, 87)
# Processing date: 1975-01-31
# (972, 87)
# Processing date: 1975-02-28
# (968, 87)
# Processing date: 1975-03-31
# (978, 87)
# Processing date: 1975-04-30
# (975, 87)
# Processing date: 1975-05-30
# (987, 87)
# Processing date: 1975-06-30
# (983, 87)
# Processing date: 1975-07-31
# (1007, 87)
# Processing date: 1975-08-29
# (999, 87)
# Processing date: 1975-09-30
# (994, 87)
# Processing date: 1975-10-31
# (969, 87)
# Processing date: 1975-11-28
# (960, 87)
# Processing date: 1975-12-31
# (957, 87)
# Processing date: 1976-01-30
# (975, 87)
# Processing date: 1976-02-27
# (1024, 87)
# Processing date: 1976-03-31
# (1004, 87)
# Processing date: 1976-04-30
# (1004, 87)
# Processing date: 1976-05-28
# (996, 87)
# Processing date: 1976-06-30
# (997, 87)
# Processing date: 1976-07-30
# (995, 87)
# Processing date: 1976-08-31
# (987, 87)
# Processing date: 1976-09-30
# (991, 87)
# Processing date: 1976-10-29
# (995, 87)
# Processing date: 1976-11-30
# (1021, 87)
# Processing date: 1976-12-31
# (1039, 87)
# Processing date: 1977-01-31
# (1050, 87)
# Processing date: 1977-02-28
# (1041, 87)
# Processing date: 1977-03-31
# (1060, 87)
# Processing date: 1977-04-29
# (1062, 87)
# Processing date: 1977-05-31
# (1065, 87)
# Processing date: 1977-06-30
# (1076, 87)
# Processing date: 1977-07-29
# (1078, 87)
# Processing date: 1977-08-31
# (1075, 87)
# Processing date: 1977-09-30
# (1068, 87)
# Processing date: 1977-10-31
# (1076, 87)
# Processing date: 1977-11-30
# (1104, 87)
# Processing date: 1977-12-30
# (1110, 87)
# Processing date: 1978-01-31
# (1108, 87)
# Processing date: 1978-02-28
# (1125, 87)
# Processing date: 1978-03-31
# (1149, 87)
# Processing date: 1978-04-28
# (1137, 87)
# Processing date: 1978-05-31
# (1149, 87)
# Processing date: 1978-06-30
# (1158, 87)
# Processing date: 1978-07-31
# (1166, 87)
# Processing date: 1978-08-31
# (1195, 87)
# Processing date: 1978-09-29
# (1191, 87)
# Processing date: 1978-10-31
# (1114, 87)
# Processing date: 1978-11-30
# (1142, 87)
# Processing date: 1978-12-29
# (1142, 87)
# Processing date: 1979-01-31
# (1147, 87)
# Processing date: 1979-02-28
# (1150, 87)
# Processing date: 1979-03-30
# (1156, 87)
# Processing date: 1979-04-30
# (1166, 87)
# Processing date: 1979-05-31
# (1163, 87)
# Processing date: 1979-06-29
# (1169, 87)
# Processing date: 1979-07-31
# (1167, 87)
# Processing date: 1979-08-31
# (1176, 87)
# Processing date: 1979-09-28
# (1164, 87)
# Processing date: 1979-10-31
# (1137, 87)
# Processing date: 1979-11-30
# (1159, 87)
# Processing date: 1979-12-31
# (1175, 87)
# Processing date: 1980-01-31
# (1147, 87)
# Processing date: 1980-02-29
# (1130, 87)
# Processing date: 1980-03-31
# (1096, 87)
# Processing date: 1980-04-30
# (1093, 87)
# Processing date: 1980-05-30
# (1108, 87)
# Processing date: 1980-06-30
# (1111, 87)
# Processing date: 1980-07-31
# (1124, 87)
# Processing date: 1980-08-29
# (1149, 87)
# Processing date: 1980-09-30
# (1150, 87)
# Processing date: 1980-10-31
# (1152, 87)
# Processing date: 1980-11-28
# (1135, 87)
# Processing date: 1980-12-31
# (1139, 87)
# Processing date: 1981-01-30
# (1158, 87)
# Processing date: 1981-02-27
# (1168, 87)
# Processing date: 1981-03-31
# (1181, 87)
# Processing date: 1981-04-30
# (1201, 87)
# Processing date: 1981-05-29
# (1216, 87)
# Processing date: 1981-06-30
# (1204, 87)
# Processing date: 1981-07-31
# (1189, 87)
# Processing date: 1981-08-31
# (1174, 87)
# Processing date: 1981-09-30
# (1177, 87)
# Processing date: 1981-10-30
# (1188, 87)
# Processing date: 1981-11-30
# (1183, 87)
# Processing date: 1981-12-31
# (1193, 87)
# Processing date: 1982-01-29
# (1175, 87)
# Processing date: 1982-02-26
# (1172, 87)
# Processing date: 1982-03-31
# (1174, 87)
# Processing date: 1982-04-30
# (1179, 87)
# Processing date: 1982-05-28
# (1184, 87)
# Processing date: 1982-06-30
# (1169, 87)
# Processing date: 1982-07-30
# (1181, 87)
# Processing date: 1982-08-31
# (1156, 87)
# Processing date: 1982-09-30
# (1164, 87)
# Processing date: 1982-10-29
# (1171, 87)
# Processing date: 1982-11-30
# (1183, 87)
# Processing date: 1982-12-31
# (1160, 87)
# Processing date: 1983-01-31
# (1193, 87)
# Processing date: 1983-02-28
# (1213, 87)
# Processing date: 1983-03-31
# (1209, 87)
# Processing date: 1983-04-29
# (1217, 87)
# Processing date: 1983-05-31
# (1265, 87)
# Processing date: 1983-06-30
# (1258, 87)
# Processing date: 1983-07-29
# (1254, 87)
# Processing date: 1983-08-31
# (1240, 87)
# Processing date: 1983-09-30
# (1241, 87)
# Processing date: 1983-10-31
# (1213, 87)
# Processing date: 1983-11-30
# (1235, 87)
# Processing date: 1983-12-30
# (1239, 87)
# Processing date: 1984-01-31
# (1238, 87)
# Processing date: 1984-02-29
# (1222, 87)
# Processing date: 1984-03-30
# (1215, 87)
# Processing date: 1984-04-30
# (1208, 87)
# Processing date: 1984-05-31
# (1212, 87)
# Processing date: 1984-06-29
# (1216, 87)
# Processing date: 1984-07-31
# (1207, 87)
# Processing date: 1984-08-31
# (1206, 87)
# Processing date: 1984-09-28
# (1197, 87)
# Processing date: 1984-10-31
# (1191, 87)
# Processing date: 1984-11-30
# (1187, 87)
# Processing date: 1984-12-31
# (1192, 87)
# Processing date: 1985-01-31
# (1215, 87)
# Processing date: 1985-02-28
# (1215, 87)
# Processing date: 1985-03-29
# (1204, 87)
# Processing date: 1985-04-30
# (1198, 87)
# Processing date: 1985-05-31
# (1184, 87)
# Processing date: 1985-06-28
# (1178, 87)
# Processing date: 1985-07-31
# (1189, 87)
# Processing date: 1985-08-30
# (1189, 87)
# Processing date: 1985-09-30
# (1175, 87)
# Processing date: 1985-10-31
# (1177, 87)
# Processing date: 1985-11-29
# (1186, 87)
# Processing date: 1985-12-31
# (1165, 87)
# Processing date: 1986-01-31
# (1170, 87)
# Processing date: 1986-02-28
# (1167, 87)
# Processing date: 1986-03-31
# (1174, 87)
# Processing date: 1986-04-30
# (1185, 87)
# Processing date: 1986-05-30
# (1171, 87)
# Processing date: 1986-06-30
# (1157, 87)
# Processing date: 1986-07-31
# (1135, 87)
# Processing date: 1986-08-29
# (1117, 87)
# Processing date: 1986-09-30
# (1123, 87)
# Processing date: 1986-10-31
# (1123, 87)
# Processing date: 1986-11-28
# (1108, 87)
# Processing date: 1986-12-31
# (1114, 87)
# Processing date: 1987-01-30
# (1116, 87)
# Processing date: 1987-02-27
# (1135, 87)
# Processing date: 1987-03-31
# (1126, 87)
# Processing date: 1987-04-30
# (1115, 87)
# Processing date: 1987-05-29
# (1121, 87)
# Processing date: 1987-06-30
# (1110, 87)
# Processing date: 1987-07-31
# (1104, 87)
# Processing date: 1987-08-31
# (1095, 87)
# Processing date: 1987-09-30
# (1100, 87)
# Processing date: 1987-10-30
# (1031, 87)
# Processing date: 1987-11-30
# (1043, 87)
# Processing date: 1987-12-31
# (1063, 87)
# Processing date: 1988-01-29
# (1047, 87)
# Processing date: 1988-02-29
# (1064, 87)
# Processing date: 1988-03-31
# (1096, 87)
# Processing date: 1988-04-29
# (1098, 87)
# Processing date: 1988-05-31
# (1081, 87)
# Processing date: 1988-06-30
# (1079, 87)
# Processing date: 1988-07-29
# (1081, 87)
# Processing date: 1988-08-31
# (1079, 87)
# Processing date: 1988-09-30
# (1076, 87)
# Processing date: 1988-10-31
# (1062, 87)
# Processing date: 1988-11-30
# (1053, 87)
# Processing date: 1988-12-30
# (1064, 87)
# Processing date: 1989-01-31
# (1052, 87)
# Processing date: 1989-02-28
# (1071, 87)
# Processing date: 1989-03-31
# (1070, 87)
# Processing date: 1989-04-28
# (1073, 87)
# Processing date: 1989-05-31
# (1070, 87)
# Processing date: 1989-06-30
# (1062, 87)
# Processing date: 1989-07-31
# (1036, 87)
# Processing date: 1989-08-31
# (1041, 87)
# Processing date: 1989-09-29
# (1045, 87)
# Processing date: 1989-10-31
# (1020, 87)
# Processing date: 1989-11-30
# (1019, 87)
# Processing date: 1989-12-29
# (1003, 87)
# Processing date: 1990-01-31
# (988, 87)
# Processing date: 1990-02-28
# (1005, 87)
# Processing date: 1990-03-30
# (1014, 87)
# Processing date: 1990-04-30
# (995, 87)
# Processing date: 1990-05-31
# (996, 87)
# Processing date: 1990-06-29
# (1005, 87)
# Processing date: 1990-07-31
# (998, 87)
# Processing date: 1990-08-31
# (963, 87)
# Processing date: 1990-09-28
# (939, 87)
# Processing date: 1990-10-31
# (918, 87)
# Processing date: 1990-11-30
# (929, 87)
# Processing date: 1990-12-31
# (943, 87)
# Processing date: 1991-01-31
# (948, 87)
# Processing date: 1991-02-28
# (977, 87)
# Processing date: 1991-03-28
# (984, 87)
# Processing date: 1991-04-30
# (989, 87)
# Processing date: 1991-05-31
# (1001, 87)
# Processing date: 1991-06-28
# (996, 87)
# Processing date: 1991-07-31
# (997, 87)
# Processing date: 1991-08-30
# (1013, 87)
# Processing date: 1991-09-30
# (1013, 87)
# Processing date: 1991-10-31
# (1035, 87)
# Processing date: 1991-11-29
# (1028, 87)
# Processing date: 1991-12-31
# (1025, 87)
# Processing date: 1992-01-31
# (1058, 87)
# Processing date: 1992-02-28
# (1070, 87)
# Processing date: 1992-03-31
# (1073, 87)
# Processing date: 1992-04-30
# (1047, 87)
# Processing date: 1992-05-29
# (1053, 87)
# Processing date: 1992-06-30
# (1043, 87)
# Processing date: 1992-07-31
# (1034, 87)
# Processing date: 1992-08-31
# (1026, 87)
# Processing date: 1992-09-30
# (1037, 87)
# Processing date: 1992-10-30
# (1048, 87)
# Processing date: 1992-11-30
# (1078, 87)
# Processing date: 1992-12-31
# (1089, 87)
# Processing date: 1993-01-29
# (1090, 87)
# Processing date: 1993-02-26
# (1085, 87)
# Processing date: 1993-03-31
# (1091, 87)
# Processing date: 1993-04-30
# (1085, 87)
# Processing date: 1993-05-28
# (1113, 87)
# Processing date: 1993-06-30
# (1113, 87)
# Processing date: 1993-07-30
# (1134, 87)
# Processing date: 1993-08-31
# (1135, 87)
# Processing date: 1993-09-30
# (1147, 87)
# Processing date: 1993-10-29
# (1151, 87)
# Processing date: 1993-11-30
# (1141, 87)
# Processing date: 1993-12-31
# (1161, 87)
# Processing date: 1994-01-31
# (1156, 87)
# Processing date: 1994-02-28
# (1162, 87)
# Processing date: 1994-03-31
# (1171, 87)
# Processing date: 1994-04-29
# (1148, 87)
# Processing date: 1994-05-31
# (1156, 87)
# Processing date: 1994-06-30
# (1167, 87)
# Processing date: 1994-07-29
# (1157, 87)
# Processing date: 1994-08-31
# (1188, 87)
# Processing date: 1994-09-30
# (1192, 87)
# Processing date: 1994-10-31
# (1174, 87)
# Processing date: 1994-11-30
# (1176, 87)
# Processing date: 1994-12-30
# (1187, 87)
# Processing date: 1995-01-31
# (1158, 87)
# Processing date: 1995-02-28
# (1162, 87)
# Processing date: 1995-03-31
# (1156, 87)
# Processing date: 1995-04-28
# (1153, 87)
# Processing date: 1995-05-31
# (1138, 87)
# Processing date: 1995-06-30
# (1157, 87)
# Processing date: 1995-07-31
# (1170, 87)
# Processing date: 1995-08-31
# (1188, 87)
# Processing date: 1995-09-29
# (1189, 87)
# Processing date: 1995-10-31
# (1153, 87)
# Processing date: 1995-11-30
# (1150, 87)
# Processing date: 1995-12-29
# (1164, 87)
# Processing date: 1996-01-31
# (1134, 87)
# Processing date: 1996-02-29
# (1164, 87)
# Processing date: 1996-03-29
# (1165, 87)
# Processing date: 1996-04-30
# (1178, 87)
# Processing date: 1996-05-31
# (1182, 87)
# Processing date: 1996-06-28
# (1161, 87)
# Processing date: 1996-07-31
# (1140, 87)
# Processing date: 1996-08-30
# (1161, 87)
# Processing date: 1996-09-30
# (1159, 87)
# Processing date: 1996-10-31
# (1133, 87)
# Processing date: 1996-11-29
# (1115, 87)
# Processing date: 1996-12-31
# (1136, 87)
# Processing date: 1997-01-31
# (1120, 87)
# Processing date: 1997-02-28
# (1114, 87)
# Processing date: 1997-03-31
# (1093, 87)
# Processing date: 1997-04-30
# (1066, 87)
# Processing date: 1997-05-30
# (1086, 87)
# Processing date: 1997-06-30
# (1103, 87)
# Processing date: 1997-07-31
# (1076, 87)
# Processing date: 1997-08-29
# (1100, 87)
# Processing date: 1997-09-30
# (1109, 87)
# Processing date: 1997-10-31
# (1085, 87)
# Processing date: 1997-11-28
# (1066, 87)
# Processing date: 1997-12-31
# (1072, 87)
# Processing date: 1998-01-30
# (1059, 87)
# Processing date: 1998-02-27
# (1061, 87)
# Processing date: 1998-03-31
# (1065, 87)
# Processing date: 1998-04-30
# (1062, 87)
# Processing date: 1998-05-29
# (1040, 87)
# Processing date: 1998-06-30
# (1024, 87)
# Processing date: 1998-07-31
# (980, 87)
# Processing date: 1998-08-31
# (945, 87)
# Processing date: 1998-09-30
# (938, 87)
# Processing date: 1998-10-30
# (925, 87)
# Processing date: 1998-11-30
# (910, 87)
# Processing date: 1998-12-31
# (914, 87)
# Processing date: 1999-01-29
# (895, 87)
# Processing date: 1999-02-26
# (891, 87)
# Processing date: 1999-03-31
# (897, 87)
# Processing date: 1999-04-30
# (903, 87)
# Processing date: 1999-05-28
# (903, 87)
# Processing date: 1999-06-30
# (902, 87)
# Processing date: 1999-07-30
# (916, 87)
# Processing date: 1999-08-31
# (905, 87)
# Processing date: 1999-09-30
# (912, 87)
# Processing date: 1999-10-29
# (890, 87)
# Processing date: 1999-11-30
# (896, 87)
# Processing date: 1999-12-31
# (913, 87)
# Processing date: 2000-01-31
# (930, 87)
# Processing date: 2000-02-29
# (934, 87)
# Processing date: 2000-03-31
# (915, 87)
# Processing date: 2000-04-28
# (904, 87)
# Processing date: 2000-05-31
# (912, 87)
# Processing date: 2000-06-30
# (907, 87)
# Processing date: 2000-07-31
# (897, 87)
# Processing date: 2000-08-31
# (897, 87)
# Processing date: 2000-09-29
# (899, 87)
# Processing date: 2000-10-31
# (894, 87)
# Processing date: 2000-11-30
# (881, 87)
# Processing date: 2000-12-29
# (910, 87)
# Processing date: 2001-01-31
# (909, 87)
# Processing date: 2001-02-28
# (898, 87)
# Processing date: 2001-03-30
# (894, 87)
# Processing date: 2001-04-30
# (907, 87)
# Processing date: 2001-05-31
# (910, 87)
# Processing date: 2001-06-29
# (909, 87)
# Processing date: 2001-07-31
# (909, 87)
# Processing date: 2001-08-31
# (919, 87)
# Processing date: 2001-09-28
# (886, 87)
# Processing date: 2001-10-31
# (896, 87)
# Processing date: 2001-11-30
# (899, 87)
# Processing date: 2001-12-31
# (930, 87)
# Processing date: 2002-01-31
# (916, 87)
# Processing date: 2002-02-28
# (921, 87)
# Processing date: 2002-03-28
# (933, 87)
# Processing date: 2002-04-30
# (967, 87)
# Processing date: 2002-05-31
# (932, 87)
# Processing date: 2002-06-28
# (935, 87)
# Processing date: 2002-07-31
# (910, 87)
# Processing date: 2002-08-30
# (908, 87)
# Processing date: 2002-09-30
# (910, 87)
# Processing date: 2002-10-31
# (899, 87)
# Processing date: 2002-11-29
# (907, 87)
# Processing date: 2002-12-31
# (913, 87)
# Processing date: 2003-01-31
# (918, 87)
# Processing date: 2003-02-28
# (892, 87)
# Processing date: 2003-03-31
# (901, 87)
# Processing date: 2003-04-30
# (912, 87)
# Processing date: 2003-05-30
# (924, 87)
# Processing date: 2003-06-30
# (924, 87)
# Processing date: 2003-07-31
# (938, 87)
# Processing date: 2003-08-29
# (953, 87)
# Processing date: 2003-09-30
# (962, 87)
# Processing date: 2003-10-31
# (954, 87)
# Processing date: 2003-11-28
# (974, 87)
# Processing date: 2003-12-31
# (969, 87)
# Processing date: 2004-01-30
# (971, 87)
# Processing date: 2004-02-27
# (975, 87)
# Processing date: 2004-03-31
# (990, 87)
# Processing date: 2004-04-30
# (986, 87)
# Processing date: 2004-05-28
# (990, 87)
# Processing date: 2004-06-30
# (992, 87)
# Processing date: 2004-07-30
# (978, 87)
# Processing date: 2004-08-31
# (971, 87)
# Processing date: 2004-09-30
# (985, 87)
# Processing date: 2004-10-29
# (992, 87)
# Processing date: 2004-11-30
# (1009, 87)
# Processing date: 2004-12-31
# (990, 87)
# Processing date: 2005-01-31
# (990, 87)
# Processing date: 2005-02-28
# (994, 87)
# Processing date: 2005-03-31
# (992, 87)
# Processing date: 2005-04-29
# (962, 87)
# Processing date: 2005-05-31
# (982, 87)
# Processing date: 2005-06-30
# (998, 87)
# Processing date: 2005-07-29
# (994, 87)
# Processing date: 2005-08-31
# (982, 87)
# Processing date: 2005-09-30
# (975, 87)
# Processing date: 2005-10-31
# (980, 87)
# Processing date: 2005-11-30
# (980, 87)
# Processing date: 2005-12-30
# (976, 87)
# Processing date: 2006-01-31
# (984, 87)
# Processing date: 2006-02-28
# (986, 87)
# Processing date: 2006-03-31
# (988, 87)
# Processing date: 2006-04-28
# (992, 87)
# Processing date: 2006-05-31
# (980, 87)
# Processing date: 2006-06-30
# (978, 87)
# Processing date: 2006-07-31
# (974, 87)
# Processing date: 2006-08-31
# (960, 87)
# Processing date: 2006-09-29
# (967, 87)
# Processing date: 2006-10-31
# (985, 87)
# Processing date: 2006-11-30
# (980, 87)
# Processing date: 2006-12-29
# (975, 87)
# Processing date: 2007-01-31
# (970, 87)
# Processing date: 2007-02-28
# (998, 87)
# Processing date: 2007-03-30
# (986, 87)
# Processing date: 2007-04-30
# (968, 87)
# Processing date: 2007-05-31
# (980, 87)
# Processing date: 2007-06-29
# (983, 87)
# Processing date: 2007-07-31
# (968, 87)
# Processing date: 2007-08-31
# (961, 87)
# Processing date: 2007-09-28
# (950, 87)
# Processing date: 2007-10-31
# (944, 87)
# Processing date: 2007-11-30
# (918, 87)
# Processing date: 2007-12-31
# (915, 87)
# Processing date: 2008-01-31
# (919, 87)
# Processing date: 2008-02-29
# (921, 87)
# Processing date: 2008-03-31
# (917, 87)
# Processing date: 2008-04-30
# (913, 87)
# Processing date: 2008-05-30
# (923, 87)
# Processing date: 2008-06-30
# (905, 87)
# Processing date: 2008-07-31
# (909, 87)
# Processing date: 2008-08-29
# (922, 87)
# Processing date: 2008-09-30
# (925, 87)
# Processing date: 2008-10-31
# (897, 87)
# Processing date: 2008-11-28
# (874, 87)
# Processing date: 2008-12-31
# (864, 87)
# Processing date: 2009-01-30
# (860, 87)
# Processing date: 2009-02-27
# (859, 87)
# Processing date: 2009-03-31
# (859, 87)
# Processing date: 2009-04-30
# (900, 87)
# Processing date: 2009-05-29
# (897, 87)
# Processing date: 2009-06-30
# (899, 87)
# Processing date: 2009-07-31
# (906, 87)
# Processing date: 2009-08-31
# (906, 87)
# Processing date: 2009-09-30
# (918, 87)
# Processing date: 2009-10-30
# (893, 87)
# Processing date: 2009-11-30
# (883, 87)
# Processing date: 2009-12-31
# (905, 87)
# Processing date: 2010-01-29
# (909, 87)
# Processing date: 2010-02-26
# (915, 87)
# Processing date: 2010-03-31
# (919, 87)
# Processing date: 2010-04-30
# (937, 87)
# Processing date: 2010-05-28
# (944, 87)
# Processing date: 2010-06-30
# (925, 87)
# Processing date: 2010-07-30
# (928, 87)
# Processing date: 2010-08-31
# (916, 87)
# Processing date: 2010-09-30
# (934, 87)
# Processing date: 2010-10-29
# (940, 87)
# Processing date: 2010-11-30
# (945, 87)
# Processing date: 2010-12-31
# (950, 87)
# Processing date: 2011-01-31
# (935, 87)
# Processing date: 2011-02-28
# (939, 87)
# Processing date: 2011-03-31
# (955, 87)
# Processing date: 2011-04-29
# (956, 87)
# Processing date: 2011-05-31
# (961, 87)
# Processing date: 2011-06-30
# (951, 87)
# Processing date: 2011-07-29
# (934, 87)
# Processing date: 2011-08-31
# (925, 87)
# Processing date: 2011-09-30
# (893, 87)
# Processing date: 2011-10-31
# (924, 87)
# Processing date: 2011-11-30
# (918, 87)
# Processing date: 2011-12-30
# (915, 87)
# Processing date: 2012-01-31
# (931, 87)
# Processing date: 2012-02-29
# (922, 87)
# Processing date: 2012-03-30
# (913, 87)
# Processing date: 2012-04-30
# (911, 87)
# Processing date: 2012-05-31
# (905, 87)
# Processing date: 2012-06-29
# (890, 87)
# Processing date: 2012-07-31
# (874, 87)
# Processing date: 2012-08-31
# (880, 87)
# Processing date: 2012-09-28
# (875, 87)
# Processing date: 2012-10-31
# (877, 87)
# Processing date: 2012-11-30
# (885, 87)
# Processing date: 2012-12-31
# (893, 87)
# Processing date: 2013-01-31
# (898, 87)
# Processing date: 2013-02-28
# (894, 87)
# Processing date: 2013-03-28
# (907, 87)
# Processing date: 2013-04-30
# (908, 87)
# Processing date: 2013-05-31
# (922, 87)
# Processing date: 2013-06-28
# (925, 87)
# Processing date: 2013-07-31
# (940, 87)
# Processing date: 2013-08-30
# (948, 87)
# Processing date: 2013-09-30
# (952, 87)
# Processing date: 2013-10-31
# (941, 87)
# Processing date: 2013-11-29
# (947, 87)
# Processing date: 2013-12-31
# (950, 87)
# Processing date: 2014-01-31
# (951, 87)
# Processing date: 2014-02-28
# (949, 87)
# Processing date: 2014-03-31
# (951, 87)
# Processing date: 2014-04-30
# (930, 87)
# Processing date: 2014-05-30
# (917, 87)
# Processing date: 2014-06-30
# (943, 87)
# Processing date: 2014-07-31
# (919, 87)
# Processing date: 2014-08-29
# (922, 87)
# Processing date: 2014-09-30
# (904, 87)
# Processing date: 2014-10-31
# (929, 87)
# Processing date: 2014-11-28
# (918, 87)
# Processing date: 2014-12-31
# (925, 87)
# Processing date: 2015-01-30
# (913, 87)
# Processing date: 2015-02-27
# (930, 87)
# Processing date: 2015-03-31
# (936, 87)
# Processing date: 2015-04-30
# (924, 87)
# Processing date: 2015-05-29
# (918, 87)
# Processing date: 2015-06-30
# (926, 87)
# Processing date: 2015-07-31
# (899, 87)
# Processing date: 2015-08-31
# (900, 87)
# Processing date: 2015-09-30
# (890, 87)
# Processing date: 2015-10-30
# (876, 87)
# Processing date: 2015-11-30
# (888, 87)
# Processing date: 2015-12-31
# (869, 87)
# Processing date: 2016-01-29
# (850, 87)
# Processing date: 2016-02-29
# (852, 87)
# Processing date: 2016-03-31
# (861, 87)
# Processing date: 2016-04-29
# (858, 87)
# Processing date: 2016-05-31
# (849, 87)
# Processing date: 2016-06-30
# (847, 87)
# Processing date: 2016-07-29
# (855, 87)
# Processing date: 2016-08-31
# (857, 87)
# Processing date: 2016-09-30
# (860, 87)
# Processing date: 2016-10-31
# (846, 87)
# Processing date: 2016-11-30
# (874, 87)
# Processing date: 2016-12-30
# (871, 87)
# Processing date: 2017-01-31
# (866, 87)
# Processing date: 2017-02-28
# (865, 87)
# Processing date: 2017-03-31
# (862, 87)
# Processing date: 2017-04-28
# (858, 87)
# Processing date: 2017-05-31
# (851, 87)
# Processing date: 2017-06-30
# (850, 87)
# Processing date: 2017-07-31
# (846, 87)
# Processing date: 2017-08-31
# (839, 87)
# Processing date: 2017-09-29
# (846, 87)
# Processing date: 2017-10-31
# (850, 87)
# Processing date: 2017-11-30
# (849, 87)
# Processing date: 2017-12-29
# (845, 87)
# Processing date: 2018-01-31
# (833, 87)
# Processing date: 2018-02-28
# (839, 87)
# Processing date: 2018-03-29
# (850, 87)
# Processing date: 2018-04-30
# (845, 87)
# Processing date: 2018-05-31
# (857, 87)
# Processing date: 2018-06-29
# (864, 87)
# Processing date: 2018-07-31
# (860, 87)
# Processing date: 2018-08-31
# (857, 87)
# Processing date: 2018-09-28
# (846, 87)
# Processing date: 2018-10-31
# (825, 87)
# Processing date: 2018-11-30
# (820, 87)
# Processing date: 2018-12-31
# (812, 87)
# Processing date: 2019-01-31
# (831, 87)
# Processing date: 2019-02-28
# (836, 87)
# Processing date: 2019-03-29
# (828, 87)
# Processing date: 2019-04-30
# (823, 87)
# Processing date: 2019-05-31
# (815, 87)
# Processing date: 2019-06-28
# (820, 87)
# Processing date: 2019-07-31
# (819, 87)
# Processing date: 2019-08-30
# (812, 87)
# Processing date: 2019-09-30
# (808, 87)
# Processing date: 2019-10-31
# (807, 87)
# Processing date: 2019-11-29
# (806, 87)
# Processing date: 2019-12-31
# (802, 87)
# Processing date: 2020-01-31
# (795, 87)
# Processing date: 2020-02-28
# (802, 87)
# Processing date: 2020-03-31
# (736, 87)
# Processing date: 2020-04-30
# (749, 87)
# Processing date: 2020-05-29
# (760, 87)
# Processing date: 2020-06-30
# (767, 87)
# Processing date: 2020-07-31
# (760, 87)
# Processing date: 2020-08-31
# (744, 87)
# Processing date: 2020-09-30
# (744, 87)
# Processing date: 2020-10-30
# (762, 87)
# Processing date: 2020-11-30
# (783, 87)
# Processing date: 2020-12-31
# (809, 87)
# Processing date: 2021-01-29
# (820, 87)
# Processing date: 2021-02-26
# (846, 87)
# Processing date: 2021-03-31
# (842, 87)
# Processing date: 2021-04-30
# (830, 87)
# Processing date: 2021-05-28
# (822, 87)
# Processing date: 2021-06-30
# (819, 87)
# Processing date: 2021-07-30
# (799, 87)
# Processing date: 2021-08-31
# (804, 87)
# Processing date: 2021-09-30
# (810, 87)
# Processing date: 2021-10-29
# (789, 87)
# Processing date: 2021-11-30
# (776, 87)
# Processing date: 2021-12-31
# (771, 87)
# Processing date: 2022-01-31
# (763, 87)
# Processing date: 2022-02-28
# (769, 87)
# Processing date: 2022-03-31
# (757, 87)
# Processing date: 2022-04-29
# (770, 87)
# Processing date: 2022-05-31
# (757, 87)
# Processing date: 2022-06-30
# (753, 87)
# Processing date: 2022-07-29
# (755, 87)
# Processing date: 2022-08-31
# (768, 87)
# Processing date: 2022-09-30
# (763, 87)
# Processing date: 2022-10-31
# (778, 87)
# Processing date: 2022-11-30
# (768, 87)
# Processing date: 2022-12-30
# (771, 87)
# Processing date: 2023-01-31
# (780, 87)
# Processing date: 2023-02-28
# (787, 87)
# Processing date: 2023-03-31
# (759, 87)
# Processing date: 2023-04-28
# (748, 87)
# Processing date: 2023-05-31
# (725, 87)
# Processing date: 2023-06-30
# (734, 87)
# Processing date: 2023-07-31
# (738, 87)
# Processing date: 2023-08-31
# (726, 87)
# Processing date: 2023-09-29
# (726, 87)
# Processing date: 2023-10-31
# (706, 87)
# Processing date: 2023-11-30
# (715, 87)
# Processing completed.

# %% [markdown]
# ## Computing excess returns (substract Risk Free Rate)

# %%
conn = sqlite3.connect('db2023.db')

# %%
query = "SELECT * FROM Z_R_matrices"
results = pd.read_sql_query(query, conn)

# %%
# Substracting risk free rate. 
 
# #After this, R_e_adj is the excess return on the table Z_R_matrices.

# Load the Fama_French table
query_ff = "SELECT dateff, rf FROM Fama_French"
fama_french = pd.read_sql_query(query_ff, conn)
fama_french["rf"] = pd.to_numeric(fama_french["rf"], errors='coerce')
# Merge the dataframes on the matching date columns
merged_data = pd.merge(results, fama_french, left_on='date', right_on='dateff')

# Subtract the 'rf' column from the 'retadj' column
merged_data['R_e_adj'] = merged_data['retadj'] - merged_data['rf']

# Drop the 'dateff' and 'rf' columns as they are no longer needed
merged_data.drop(columns=['dateff', 'rf'], inplace=True)

# Write the modified dataframe back to the SQLite database
merged_data.to_sql('Z_R_matrices', conn, if_exists='replace', index=False)
# Out:
# 641232

# %%
conn.close()

# %% [markdown]
# ## Export to CSV

# %%
# Connect to the SQLite database
conn = sqlite3.connect('db2023.db')

# Load the table into a pandas DataFrame
df = pd.read_sql_query("SELECT * FROM Z_R_matrices", conn)

# Export the DataFrame to a CSV file
df.to_csv('Z_R_matrices.csv', index=False)

# Close the database connection
conn.close()
